# %%
import pandas as pd

# %%
annual = pd.read_excel('../data/fed_agency_spending.xlsx', index_col=False )
annual.head()
# Out:
#   Table 4.1 - OUTLAYS BY AGENCY:  1962 - 2027 Unnamed: 1 Unnamed: 2  \
# 0                    (in millions of dollars)        NaN        NaN
# 1                    Department or other unit       1962       1963
# 2                          Legislative Branch        196        192
# 3                             Judicial Branch         57         62
# 4                   Department of Agriculture       6437       7414
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       1964       1965       1966       1967       1968       1969
# 2        199        212        234        252        269        289
# 3         66         75         80         88         94        110
# 4       7569       6940       5633       5952       7430       8446
#
#   Unnamed: 9  ... Unnamed: 58 Unnamed: 59 Unnamed: 60 Unnamed: 61  \
# 0        NaN  ...         NaN         NaN         NaN         NaN
# ...

# %%
#renaming dept column
annual.rename(columns={'Table 4.1 - OUTLAYS BY AGENCY:  1962 - 2027':'department'},
             inplace=True)
annual.head()
# Out:
#                   department Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0   (in millions of dollars)        NaN        NaN        NaN        NaN
# 1   Department or other unit       1962       1963       1964       1965
# 2         Legislative Branch        196        192        199        212
# 3            Judicial Branch         57         62         66         75
# 4  Department of Agriculture       6437       7414       7569       6940
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 58  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1       1966       1967       1968       1969       1970  ...        2018
# 2        234        252        269        289        353  ...        4675
# 3         80         88         94        110        133  ...        7778
# 4       5633       5952       7430       8446       8412  ...      136716
#
#   Unnamed: 59 Unnamed: 60 Unnamed: 61    Unnamed: 62    Unnamed: 63  \
# ...

# %%
# droping index so i can set columns as the first second row in the table
annual.set_index('department',inplace=True)
annual.head()
# Out:
#                           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# department
# (in millions of dollars)         NaN        NaN        NaN        NaN
# Department or other unit        1962       1963       1964       1965
# Legislative Branch               196        192        199        212
# Judicial Branch                   57         62         66         75
# Department of Agriculture       6437       7414       7569       6940
#
#                           Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# department
# (in millions of dollars)         NaN        NaN        NaN        NaN
# Department or other unit        1966       1967       1968       1969
# Legislative Branch               234        252        269        289
# Judicial Branch                   80         88         94        110
# Department of Agriculture       5633       5952       7430       8446
#
#                           Unnamed: 9 Unnamed: 10  ... Unnamed: 58 Unnamed: 59  \
# ...

# %%
annual = annual.T
annual.head()
# Out:
# department (in millions of dollars) Department or other unit  \
# Unnamed: 1                      NaN                     1962
# Unnamed: 2                      NaN                     1963
# Unnamed: 3                      NaN                     1964
# Unnamed: 4                      NaN                     1965
# Unnamed: 5                      NaN                     1966
#
# department Legislative Branch Judicial Branch Department of Agriculture  \
# Unnamed: 1                196              57                      6437
# Unnamed: 2                192              62                      7414
# Unnamed: 3                199              66                      7569
# Unnamed: 4                212              75                      6940
# Unnamed: 5                234              80                      5633
#
# department Department of Commerce Department of Defense--Military Programs  \
# Unnamed: 1                    215                                    50111
# ...

# %%
annual = annual[['Department or other unit','Department of Agriculture']]
annual.head()
# Out:
# department Department or other unit Department of Agriculture
# Unnamed: 1                     1962                      6437
# Unnamed: 2                     1963                      7414
# Unnamed: 3                     1964                      7569
# Unnamed: 4                     1965                      6940
# Unnamed: 5                     1966                      5633

# %%
print(annual.columns)
# Out:
# Index(['Department or other unit', 'Department of Agriculture'], dtype='object', name='department')

# %%
annual.head()
# Out:
# department Department or other unit Department of Agriculture
# Unnamed: 1                     1962                      6437
# Unnamed: 2                     1963                      7414
# Unnamed: 3                     1964                      7569
# Unnamed: 4                     1965                      6940
# Unnamed: 5                     1966                      5633

# %%
annual = annual.rename(columns={'Department or other unit': 'year','Department of Agriculture': 'dept_agr_fund'})
annual.head()
# Out:
# department  year dept_agr_fund
# Unnamed: 1  1962          6437
# Unnamed: 2  1963          7414
# Unnamed: 3  1964          7569
# Unnamed: 4  1965          6940
# Unnamed: 5  1966          5633

# %%
print(annual.columns)
index_name = annual.index.names
print(index_name)
# Out:
# Index(['year', 'dept_agr_fund'], dtype='object', name='department')
# [None]

# %% [markdown]
# ---
# # Why doesnt the index let me rename the index!

# %%
annual.rename_axis(index={'department': 'index'},inplace=True)
annual.head()
# Out:
# department  year dept_agr_fund
# Unnamed: 1  1962          6437
# Unnamed: 2  1963          7414
# Unnamed: 3  1964          7569
# Unnamed: 4  1965          6940
# Unnamed: 5  1966          5633

# %% [markdown]
# ---

# %%
# making sure column data types are int 
annual.dtypes
# Out:
# department
# year             object
# dept_agr_fund    object
# dtype: object

# %%
annual.iloc[15:17]
# Out:
# department   year dept_agr_fund
# Unnamed: 16    TQ          5009
# Unnamed: 17  1977         23287

# %%
annual.drop('Unnamed: 16',inplace=True)
annual.head()
# Out:
# department  year dept_agr_fund
# Unnamed: 1  1962          6437
# Unnamed: 2  1963          7414
# Unnamed: 3  1964          7569
# Unnamed: 4  1965          6940
# Unnamed: 5  1966          5633

# %%
#Year is not free for string 
annual.iloc[14:18]
# Out:
# department   year dept_agr_fund
# Unnamed: 15  1976         17682
# Unnamed: 17  1977         23287
# Unnamed: 18  1978         30179
# Unnamed: 19  1979         31698

# %%
annual.tail()
# Out:
# department            year dept_agr_fund
# Unnamed: 63  2023 estimate        207780
# Unnamed: 64  2024 estimate        213693
# Unnamed: 65  2025 estimate        202366
# Unnamed: 66  2026 estimate        200921
# Unnamed: 67  2027 estimate        203001

# %%
annual["year"] = annual["year"].astype('str')
annual["year"] = annual["year"].str.replace("estimate", "")
annual.tail()
# Out:
# department    year dept_agr_fund
# Unnamed: 63  2023         207780
# Unnamed: 64  2024         213693
# Unnamed: 65  2025         202366
# Unnamed: 66  2026         200921
# Unnamed: 67  2027         203001

# %%
annual.head()
# Out:
# department  year dept_agr_fund
# Unnamed: 1  1962          6437
# Unnamed: 2  1963          7414
# Unnamed: 3  1964          7569
# Unnamed: 4  1965          6940
# Unnamed: 5  1966          5633

# %%
annual['year'] = annual['year'].astype('int')
annual.dtypes
# Out:
# department
# year              int64
# dept_agr_fund    object
# dtype: object

# %%
annual['dept_agr_fund'] = annual['dept_agr_fund'].astype('int')

# %%
annual.dtypes
# Out:
# department
# year             int64
# dept_agr_fund    int64
# dtype: object

# %%
annual.to_csv('../data/clean_agricul_fund.csv',index=False)
