# %%
import pandas as pd

# %%
# weather cleaned  
url = 'https://drive.google.com/file/d/18ukSSj2W_OzawxGAShODaKX_CKGVHTxw/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df1 = pd.read_csv(path)
df1.columns = df1.columns.str.lower()
df1.head()
df1.dtypes
# Out:
# year                   int64
# month                  int64
# state                 object
# precipitation(in)    float64
# dtype: object

# %%
# cleaned data is posted on drive demo to pull 
url = 'https://drive.google.com/file/d/1l6pQ12hfCbyGxMBdrXNMrjqmZKLvArEm/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df2 = pd.read_csv(path)
df2.head()
df2.dtypes
# Out:
# value      float64
# anomaly    float64
# month        int64
# year         int64
# state       object
# dtype: object

# %%
# cleaned data is posted on drive demo to pull 
url = 'https://drive.google.com/file/d/1XK-3kuuBnmCZB_13oCLaF93iyRBATpc7/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df3 = pd.read_csv(path)
df3.columns = df3.columns.str.lower()
df3.head()
df3.dtypes
# Out:
# month            int64
# year             int64
# state           object
# area (acres)     int64
# population       int64
# dtype: object

# %%
# cleaned data is posted on drive demo to pull 
url = 'https://drive.google.com/file/d/1obDJM4AxTSsF5oSvdWUlaM95t90NezpP/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df4 = pd.read_csv(path)
df4.rename(columns={'fire_discovery_year':'year','fire_discovery_month':'month','origin_state':'state'},inplace=True)
df4.head()
# Out:
#   unique_fire_identifier   lattitude  longitude  acres_burned fire_cause  \
# 0      2003-WYCMX-200237 -105.563067  44.603340    139.091837    Unknown
# 1      2004-CABDU-006784 -117.076679  34.733894   1906.698008    Unknown
# 2      2008-IDGBK-000002 -116.216680  43.666673    685.728842    Unknown
# 3      2008-IDCTF-008902 -111.426912  42.096336     20.000000    Unknown
# 4      2008-AZPNF-000975 -112.072414  34.598306     77.946287    Unknown
#
#         fire_discovery_dt      incident_name  IsFSAssisted   origin_county  \
# 0  2003/01/01 06:59:59+00           SCHWARTZ           1.0        Campbell
# 1  2004/07/06 01:04:00+00            MENTONE           1.0  San Bernardino
# 2  2008/07/22 15:10:00+00  NIFC RAMP SUPPORT           1.0             Ada
# 3  2008/09/08 13:34:59+00     St. Charles RX           0.0       Bear Lake
# 4  2008/10/07 18:16:00+00   Mingus/Cherry Rx           0.0         Yavapai
#
#   state  year  month
# 0    WY  2003      1
# 1    CA  2004      7
# ...

# %%
df4.dtypes
# Out:
# unique_fire_identifier     object
# lattitude                 float64
# longitude                 float64
# acres_burned              float64
# fire_cause                 object
# fire_discovery_dt          object
# incident_name              object
# IsFSAssisted              float64
# origin_county              object
# state                      object
# year                        int64
# month                       int64
# dtype: object

# %%
# cleaned data is posted on drive demo to pull 
url = 'https://drive.google.com/file/d/1NXMhq2D1-xH0W5ZFW_dcDJWuRmGd14LU/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df5 = pd.read_csv(path)
df5.head()
df5.dtypes
# Out:
# year            int64
# fires           int64
# acres           int64
# doi_agencies    int64
# total           int64
# dtype: object

# %%
# cleaned data is posted on drive demo to pull 
url = 'https://drive.google.com/file/d/1K3Z-IDEU439wL0d395CZMUcKqQeWkNxW/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df6 = pd.read_csv(path)
df6.head()
df7.dtypes
# Out:
# year             int64
# dept_agr_fund    int64
# month            int64
# dtype: object

# %%
# cleaned data is posted on drive demo to pull 
url = 'https://drive.google.com/file/d/1nZ6_qdckhCp51XshRRfqdn8CQTgkzzuk/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df7 = pd.read_csv(path)
df7.head()
# Out:
#    year  dept_agr_fund  month
# 0  1962           6437      1
# 1  1962           6437      2
# 2  1962           6437      3
# 3  1962           6437      4
# 4  1962           6437      5

# %%
# temp df2
merge1 = pd.merge(left=df4, right=df2 ,how='left',on=['year','month','state'])
# temp df2
merge1[100000:200000]
# Out:
#        unique_fire_identifier   lattitude  longitude  acres_burned  \
# 100000      2018-AZCNF-000964 -110.690711  32.337205      0.100000
# 100001      2018-CALAC-308110 -118.393602  34.273375    775.071170
# 100002      2018-WAPCS-000304 -123.505515  46.535165      0.100000
# 100003      2018-MTBRF-018265 -114.068713  45.813896      5.000000
# 100004      2018-MTBRF-018266 -114.067713  45.810896      5.000000
# ...                       ...         ...        ...           ...
# 199995      2021-OKCNA-002096  -94.637457  35.753576      1.600000
# 199996      2021-ORDEF-000971 -121.316014  43.905715      0.100000
# 199997      2021-MTCRA-210529 -108.573112  45.427147      0.100000
# 199998      2021-WASES-000580 -120.800115  47.120236      0.100000
# 199999      2021-WAYAA-000092 -120.453903  46.505839    813.342685
#
#           fire_cause       fire_discovery_dt           incident_name  \
# 100000         Human  2018/10/11 06:46:54+00                     964
# ...

# %%
# popu df3

merge2 = pd.merge(left=merge1, right=df3 ,how='left',on=['year','month','state'])
merge2[100000:200000]
# Out:
#        unique_fire_identifier   lattitude  longitude  acres_burned  \
# 100000      2018-AZCNF-000964 -110.690711  32.337205      0.100000
# 100001      2018-CALAC-308110 -118.393602  34.273375    775.071170
# 100002      2018-WAPCS-000304 -123.505515  46.535165      0.100000
# 100003      2018-MTBRF-018265 -114.068713  45.813896      5.000000
# 100004      2018-MTBRF-018266 -114.067713  45.810896      5.000000
# ...                       ...         ...        ...           ...
# 199995      2021-OKCNA-002096  -94.637457  35.753576      1.600000
# 199996      2021-ORDEF-000971 -121.316014  43.905715      0.100000
# 199997      2021-MTCRA-210529 -108.573112  45.427147      0.100000
# 199998      2021-WASES-000580 -120.800115  47.120236      0.100000
# 199999      2021-WAYAA-000092 -120.453903  46.505839    813.342685
#
#           fire_cause       fire_discovery_dt           incident_name  \
# 100000         Human  2018/10/11 06:46:54+00                     964
# ...

# %%
# drought df6


merge3 = pd.merge(left=merge2, right=df6 ,how='left',on=['year','month','state'])
merge3[100000:200000]
# Out:
#        unique_fire_identifier   lattitude  longitude  acres_burned  \
# 100000      2018-AZCNF-000964 -110.690711  32.337205      0.100000
# 100001      2018-CALAC-308110 -118.393602  34.273375    775.071170
# 100002      2018-WAPCS-000304 -123.505515  46.535165      0.100000
# 100003      2018-MTBRF-018265 -114.068713  45.813896      5.000000
# 100004      2018-MTBRF-018266 -114.067713  45.810896      5.000000
# ...                       ...         ...        ...           ...
# 199995      2021-OKCNA-002096  -94.637457  35.753576      1.600000
# 199996      2021-ORDEF-000971 -121.316014  43.905715      0.100000
# 199997      2021-MTCRA-210529 -108.573112  45.427147      0.100000
# 199998      2021-WASES-000580 -120.800115  47.120236      0.100000
# 199999      2021-WAYAA-000092 -120.453903  46.505839    813.342685
#
#           fire_cause       fire_discovery_dt           incident_name  \
# 100000         Human  2018/10/11 06:46:54+00                     964
# ...

# %%
# weather df1
merge4 = pd.merge(left=merge3, right=df1 ,how='left',on=['year','month','state'])
merge4[100000:200000]
# Out:
#        unique_fire_identifier   lattitude  longitude  acres_burned  \
# 100000      2018-AZCNF-000964 -110.690711  32.337205      0.100000
# 100001      2018-CALAC-308110 -118.393602  34.273375    775.071170
# 100002      2018-WAPCS-000304 -123.505515  46.535165      0.100000
# 100003      2018-MTBRF-018265 -114.068713  45.813896      5.000000
# 100004      2018-MTBRF-018266 -114.067713  45.810896      5.000000
# ...                       ...         ...        ...           ...
# 199995      2021-OKCNA-002096  -94.637457  35.753576      1.600000
# 199996      2021-ORDEF-000971 -121.316014  43.905715      0.100000
# 199997      2021-MTCRA-210529 -108.573112  45.427147      0.100000
# 199998      2021-WASES-000580 -120.800115  47.120236      0.100000
# 199999      2021-WAYAA-000092 -120.453903  46.505839    813.342685
#
#           fire_cause       fire_discovery_dt           incident_name  \
# 100000         Human  2018/10/11 06:46:54+00                     964
# ...

# %%
whole = merge4.drop(columns='fire_discovery_dt')
whole.to_csv('../data/complete_fire.csv',index=False)

# %%
# dept fund df7
# annual fire supp df5
